# %%
import pandas as pd

# %%
df = pd.read_csv('../data/house_race_2020_clean.csv')
df
# Out:
#                Candidate Party  Vote      State  District  Incumbent  Winner  \
# 0             Jerry Carl     R  64.9    Alabama         1      False    True
# 1         James Averhart     D  35.0    Alabama         1      False   False
# 2            Barry Moore     R  65.3    Alabama         2      False    True
# 3    Phyllis Harvey-Hall     D  34.6    Alabama         2      False   False
# 4                 Mike D     R  67.5    Alabama         3       True    True
# ..                   ...   ...   ...        ...       ...        ...     ...
# 888        Tricia Zunker     D  39.2  Wisconsin         7      False   False
# 889       Mike Gallagher     R  64.0  Wisconsin         8       True    True
# 890         Amanda Stuck     D  36.0  Wisconsin         8      False   False
# 891           Liz Cheney     R  68.6    Wyoming         1       True    True
# 892        Lynnette Grey     D  24.6    Wyoming         1      False   False
#
#       Raised    Spent
# ...

# %%
georgia_rows = {'Candidate': ['Nikema Williams','Angela Stanton'],
               'Party':['D','R'],
               'Vote': [85.2, 14.9],
               'State': ['Georgia','Georgia'],
               'District':[5,5],
               'Incumbent':[False,False],
               'Winner': [True,False],
               'Raised': [553964,305279],
               'Spent': [362801,301338]}

# %%
df = pd.concat([df, pd.DataFrame(georgia_rows)]).reset_index(drop = True)
df
# Out:
#                Candidate Party  Vote      State  District  Incumbent  Winner  \
# 0             Jerry Carl     R  64.9    Alabama         1      False    True
# 1         James Averhart     D  35.0    Alabama         1      False   False
# 2            Barry Moore     R  65.3    Alabama         2      False    True
# 3    Phyllis Harvey-Hall     D  34.6    Alabama         2      False   False
# 4                 Mike D     R  67.5    Alabama         3       True    True
# ..                   ...   ...   ...        ...       ...        ...     ...
# 890         Amanda Stuck     D  36.0  Wisconsin         8      False   False
# 891           Liz Cheney     R  68.6    Wyoming         1       True    True
# 892        Lynnette Grey     D  24.6    Wyoming         1      False   False
# 893      Nikema Williams     D  85.2    Georgia         5      False    True
# 894       Angela Stanton     R  14.9    Georgia         5      False   False
#
#       Raised    Spent
# ...

# %%
df
# Out:
#                Candidate Party  Vote      State  District  Incumbent  Winner  \
# 0             Jerry Carl     R  64.9    Alabama         1      False    True
# 1         James Averhart     D  35.0    Alabama         1      False   False
# 2            Barry Moore     R  65.3    Alabama         2      False    True
# 3    Phyllis Harvey-Hall     D  34.6    Alabama         2      False   False
# 4                 Mike D     R  67.5    Alabama         3       True    True
# ..                   ...   ...   ...        ...       ...        ...     ...
# 890         Amanda Stuck     D  36.0  Wisconsin         8      False   False
# 891           Liz Cheney     R  68.6    Wyoming         1       True    True
# 892        Lynnette Grey     D  24.6    Wyoming         1      False   False
# 893      Nikema Williams     D  85.2    Georgia         5      False    True
# 894       Angela Stanton     R  14.9    Georgia         5      False   False
#
#       Raised    Spent
# ...

# %%
df.to_csv('../data/house_race_2020_clean.csv')
